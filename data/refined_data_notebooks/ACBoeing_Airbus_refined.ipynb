# %%
import pandas as pd
import os

# %%
df = pd.read_csv('types_and_annual_pax2.csv')
df.head()
# Out:
#    Code                                Description  pax_1990  pax_1991  \
# 0     7                         Aero Commander 200       NaN       NaN
# 1     8                          Aero Macchi AL-60       NaN       NaN
# 2     9                               Aeronca 7-AC       NaN       NaN
# 3    10  Beech Bonanza 35A/C/D/E/G/H/J/K/S/V/  36A       NaN       NaN
# 4    20                            Bellanca CH-300       NaN       NaN
#
#    pax_1992  pax_1993  pax_1994  pax_1995  pax_1996  pax_1997  ...  pax_2013  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN  ...       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN  ...       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN  ...       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN  ...     933.0
# 4       NaN       NaN       NaN       NaN       NaN       NaN  ...       NaN
#
#    pax_2014  pax_2015  pax_2016  pax_2017  pax_2018  pax_2019  pax_2020  \
# ...

# %%
# Remove 'pax_' from the column names
new_column_names = {col: col.replace('pax_', '') for col in df.columns}

# Rename the columns in the DataFrame
df = df.rename(columns=new_column_names)

# %%
df.head()
# Out:
#    Code                                Description  1990  1991  1992  1993  \
# 0     7                         Aero Commander 200   NaN   NaN   NaN   NaN
# 1     8                          Aero Macchi AL-60   NaN   NaN   NaN   NaN
# 2     9                               Aeronca 7-AC   NaN   NaN   NaN   NaN
# 3    10  Beech Bonanza 35A/C/D/E/G/H/J/K/S/V/  36A   NaN   NaN   NaN   NaN
# 4    20                            Bellanca CH-300   NaN   NaN   NaN   NaN
#
#    1994  1995  1996  1997  ...   2013   2014   2015   2016   2017   2018  \
# 0   NaN   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 1   NaN   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 2   NaN   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 3   NaN   NaN   NaN   NaN  ...  933.0  943.0  517.0  640.0  571.0  487.0
# 4   NaN   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
#
#     2019   2020  2021  2022
# 0    NaN    NaN   NaN   NaN
# ...

# %%
# Filter rows where 'Description' column contains the string '737'
filtered_df = df[df['Description'].str.contains('737')]

# Create a new DataFrame with the filtered rows
boeing_df = filtered_df.copy()

# %%
boeing_df
# Out:
#      Code                 Description        1990        1991        1992  \
# 248   612  Boeing 737-700/700LR/Max 7         NaN         NaN         NaN
# 250   614              Boeing 737-800         NaN         NaN         NaN
# 251   615          Boeing 737-5/600LR         NaN         NaN         NaN
# 252   616              Boeing 737-500   1416259.0   4927516.0  10444046.0
# 253   617              Boeing 737-400   5996722.0   8506964.0   9645313.0
# 254   618            Boeing 737-300LR         NaN         NaN    290372.0
# 255   619              Boeing 737-300  56432274.0  58666232.0  58827415.0
# 256   620          Boeing 737-100/200  50398565.0  48136649.0  46099426.0
# 257   621             Boeing 737-200C   4183816.0   4344816.0   4015859.0
# 269   633              Boeing 737-600         NaN         NaN         NaN
# 270   634              Boeing 737-900         NaN         NaN         NaN
# 353   737            Boeing 737 Max 7         NaN         NaN         NaN
# ...

# %%
# Reset the index and drop the old index
boeing_df = boeing_df.reset_index(drop=True)

# %%
boeing_df.columns
# Out:
# Index(['Code', 'Description', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')

# %%
# Assuming you have a DataFrame named boeing_df
# First, create the new DataFrame BAcount_df with the specified columns
BAcount_df = boeing_df[['Code', 'Description', '2022']].copy()

# Next, drop rows with NaN values in the '2022' column
BAcount_df = BAcount_df.dropna(subset=['2022'])

# Calculate the sum of '2022' values
total_2022 = BAcount_df['2022'].sum()

# Calculate the percentage for each row's value in the '2022' column
BAcount_df['percentage'] = (BAcount_df['2022'] / total_2022) * 100

# Reset the index of the DataFrame
BAcount_df.reset_index(drop=True, inplace=True)

BAcount_df
# Out:
#    Code                 Description         2022  percentage
# 0   612  Boeing 737-700/700LR/Max 7   93612436.0   29.283402
# 1   614              Boeing 737-800  145398174.0   45.482773
# 2   616              Boeing 737-500       1351.0    0.000423
# 3   617              Boeing 737-400     191011.0    0.059751
# 4   619              Boeing 737-300     145093.0    0.045387
# 5   620          Boeing 737-100/200       4768.0    0.001492
# 6   634              Boeing 737-900    3366586.0    1.053120
# 7   838         Boeing B737 Max 800   13647138.0    4.269034
# 8   839         Boeing B737 Max 900    9961654.0    3.116158
# 9   888            Boeing 737-900ER   53349249.0   16.688461

# %%
BAcount_df.to_excel('BAcount.xlsx', index=False)

# %%
# Create a regex pattern to match any of the strings
pattern = r'A318|A319|A320|A321'

# Filter the DataFrame to get rows with the desired strings in the 'Description' column
A320_df = df[df['Description'].str.contains(pattern, regex=True)]

# Display the filtered DataFrame
A320_df
# Out:
#      Code                    Description       1990       1991       1992  \
# 329   694  Airbus Industrie A320-100/200  1013040.0  3069473.0  6352634.0
# 333   698          Airbus Industrie A319        NaN        NaN        NaN
# 334   699       Airbus Industrie A321/Lr        NaN        NaN        NaN
# 341   719     Airbus Industrie A319-200n        NaN        NaN        NaN
# 343   721     Airbus Industrie A321-200n        NaN        NaN        NaN
# 344   722     Airbus Industrie A320-200n        NaN        NaN        NaN
#
#           1993        1994        1995        1996        1997  ...  \
# 329  8989030.0  13438598.0  14926262.0  15309186.0  17489675.0  ...
# 333        NaN         NaN         NaN         NaN    721741.0  ...
# 334        NaN         NaN         NaN         NaN         NaN  ...
# 341        NaN         NaN         NaN         NaN         NaN  ...
# 343        NaN         NaN         NaN         NaN         NaN  ...
# ...

# %%
A320_df = A320_df.drop('Code', axis=1)
A320_df
# Out:
#                        Description       1990       1991       1992  \
# 329  Airbus Industrie A320-100/200  1013040.0  3069473.0  6352634.0
# 333          Airbus Industrie A319        NaN        NaN        NaN
# 334       Airbus Industrie A321/Lr        NaN        NaN        NaN
# 341     Airbus Industrie A319-200n        NaN        NaN        NaN
# 343     Airbus Industrie A321-200n        NaN        NaN        NaN
# 344     Airbus Industrie A320-200n        NaN        NaN        NaN
#
#           1993        1994        1995        1996        1997        1998  \
# 329  8989030.0  13438598.0  14926262.0  15309186.0  17489675.0  20229949.0
# 333        NaN         NaN         NaN         NaN    721741.0   5522547.0
# 334        NaN         NaN         NaN         NaN         NaN         NaN
# 341        NaN         NaN         NaN         NaN         NaN         NaN
# 343        NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
A320_df = A320_df.reset_index(drop=True)

# %%
A320count_df = A320_df[['Description', '2022']].copy()

# Next, drop rows with NaN values in the '2022' column
A320count_df = A320count_df.dropna(subset=['2022'])

# Calculate the sum of '2022' values
sum_2022 = A320count_df['2022'].sum()

# Calculate the percentage for each row's value in the '2022' column
A320count_df['percentage'] = (A320count_df['2022'] / sum_2022) * 100

# Reset the index of the DataFrame
A320count_df.reset_index(drop=True, inplace=True)

A320count_df
# Out:
#                      Description        2022  percentage
# 0  Airbus Industrie A320-100/200  76344110.0   30.964324
# 1          Airbus Industrie A319  42414011.0   17.202652
# 2       Airbus Industrie A321/Lr  87371360.0   35.436854
# 3     Airbus Industrie A321-200n  14262808.0    5.784837
# 4     Airbus Industrie A320-200n  26162777.0   10.611332

# %%
A320count_df.to_excel('A320count.xlsx', index=False)
